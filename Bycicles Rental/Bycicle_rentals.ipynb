# %% [markdown]
# # Bycicles rental analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=[10,5]

# %% [markdown]
# ## Loading the bike data

# %%
bike_data = pd.read_csv('day.csv')
bike_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446     331         654
# 1             2  0.363478  0.353739  0.696087   0.248539     131         670
# 2             1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3             1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4             1  0.226957  0.229270  0.436957   0.186900      82        1518
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# 730  2729
#
# [731 rows x 16 columns]

# %% [markdown]
# We first convert the date to a float since it is a string

# %%
bike_data['date']=pd.to_datetime(bike_data['dteday'])

# %%
bike_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0             2  0.344167  0.363625  0.805833   0.160446     331         654
# 1             2  0.363478  0.353739  0.696087   0.248539     131         670
# 2             1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3             1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4             1  0.226957  0.229270  0.436957   0.186900      82        1518
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt       date
# 0     985 2011-01-01
# 1     801 2011-01-02
# 2    1349 2011-01-03
# 3    1562 2011-01-04
# 4    1600 2011-01-05
# ..    ...        ...
# 726  2114 2012-12-27
# 727  3095 2012-12-28
# 728  1341 2012-12-29
# 729  1796 2012-12-30
# 730  2729 2012-12-31
#
# [731 rows x 17 columns]

# %% [markdown]
# ## Play with the data

# %%
plt.scatter(bike_data['date'],bike_data['cnt'],c=bike_data['weathersit'])
plt.xlabel('Date (YYYY-MM)')
plt.ylabel('Bycicles Rented')
plt.show()

# %%
print(' Mean number of bikes rented on weather 1:',bike_data[bike_data['weathersit']==1]['cnt'].mean(),'\n',
      'Mean number of bikes rented on weather 2:',bike_data[bike_data['weathersit']==2]['cnt'].mean(),'\n',
      'Mean number of bikes rented on weather 3:',bike_data[bike_data['weathersit']==3]['cnt'].mean())
# Out:
#  Mean number of bikes rented on weather 1: 4876.7861771058315
#  Mean number of bikes rented on weather 2: 4035.862348178138
#  Mean number of bikes rented on weather 3: 1803.2857142857142

# %% [markdown]
# Seems like the weather 3 is rainy since the mean number of bycles rented on those days is way lower than the others.

# %%
plt.scatter(bike_data['atemp'],bike_data['cnt'])
plt.xlabel('Normalised Temperature')
plt.ylabel('Bycicles Rented')
plt.show()

# %%
bike_data[['cnt','atemp']].corr()
# Out:
#             cnt     atemp
# cnt    1.000000  0.631066
# atemp  0.631066  1.000000

# %%
bike_data[['cnt','temp']].corr()
# Out:
#            cnt      temp
# cnt   1.000000  0.627494
# temp  0.627494  1.000000

# %%
bike_data[['cnt','atemp','temp','hum','windspeed','weathersit']].corr()
# Out:
#                  cnt     atemp      temp       hum  windspeed  weathersit
# cnt         1.000000  0.631066  0.627494 -0.100659  -0.234545   -0.297391
# atemp       0.631066  1.000000  0.991702  0.139988  -0.183643   -0.121583
# temp        0.627494  0.991702  1.000000  0.126963  -0.157944   -0.120602
# hum        -0.100659  0.139988  0.126963  1.000000  -0.248489    0.591045
# windspeed  -0.234545 -0.183643 -0.157944 -0.248489   1.000000    0.039511
# weathersit -0.297391 -0.121583 -0.120602  0.591045   0.039511    1.000000

# %% [markdown]
# # LEARN

# %% [markdown]
# ## Multilinear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(bike_data['atemp'].values.reshape(-1,1), bike_data['cnt'].values.reshape(-1,1))
# Out:
# LinearRegression()

# %%
plt.scatter(bike_data['atemp'],bike_data['cnt'])
plt.xlabel('Normalized Temperature')
plt.ylabel('Bycicles Rented')
plt.plot(bike_data['atemp'],lr.predict(bike_data['atemp'].values.reshape(-1,1)),'--r')
plt.show()

# %%
training_set = bike_data[bike_data['date'] < '2012-06-01']
validation_set = bike_data[bike_data['date'] >= '2012-06-01']

training_inputs = training_set[['atemp', 'workingday', 'hum', 'weathersit', 'windspeed']].values
training_outputs = training_set[['cnt']].values

validation_inputs = validation_set[['atemp', 'workingday', 'hum', 'weathersit', 'windspeed']].values
validation_outputs = validation_set[['cnt']].values

lr.fit(training_inputs,training_outputs)
# Out:
# LinearRegression()

# %%
plt.scatter(training_set['date'], training_set['cnt'])
plt.scatter(training_set['date'], lr.predict(training_inputs))
plt.show()

# %%
plt.scatter(validation_set['date'], validation_set['cnt'])
plt.scatter(validation_set['date'], lr.predict(validation_inputs))
plt.show()

rmse=np.sqrt(((lr.predict(validation_inputs)-validation_outputs)**2).mean())
print('Root mean square error for this model:',rmse)
# Out:
# Root mean square error for this model: 2139.201362460237

# %% [markdown]
# Seems that this analysis is not working very well, we need to go back

# %% [markdown]
# # Back to phase 2

# %% [markdown]
# ## Adding new features

# %%
bike_data['last_week'] = (bike_data['cnt'].cumsum() - bike_data['cnt'].cumsum().shift(7))/7
bike_data = bike_data.dropna()

# %%
bike_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 7             2  0.165000  0.162254  0.535833   0.266804      68         891
# 8             1  0.138333  0.116175  0.434167   0.361950      54         768
# 9             1  0.150833  0.150888  0.482917   0.223267      41        1280
# 10            2  0.169091  0.191464  0.686364   0.122132      43        1220
# 11            1  0.172727  0.160473  0.599545   0.304627      25        1137
# ..          ...       ...       ...       ...        ...     ...         ...
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt       date    last_week
# 7     959 2011-01-08  1341.000000
# 8     822 2011-01-09  1344.000000
# 9    1321 2011-01-10  1340.000000
# 10   1263 2011-01-11  1297.285714
# 11   1162 2011-01-12  1234.714286
# ..    ...        ...          ...
# 726  2114 2012-12-27  1663.857143
# 727  3095 2012-12-28  1588.428571
# 728  1341 2012-12-29  1530.142857
# 729  1796 2012-12-30  1531.428571
# 730  2729 2012-12-31  1789.857143
#
# [724 rows x 18 columns]

# %%
training_set = bike_data[bike_data['date'] < '2012-06-01']
validation_set = bike_data[bike_data['date'] >= '2012-06-01']

training_inputs = training_set[['atemp', 'workingday', 'hum', 'weathersit', 'windspeed', 'last_week']].values
training_outputs = training_set[['cnt']].values

validation_inputs = validation_set[['atemp', 'workingday', 'hum', 'weathersit', 'windspeed', 'last_week']].values
validation_outputs = validation_set[['cnt']].values

lr.fit(training_inputs,training_outputs)

plt.scatter(training_set['date'], training_set['cnt'])
plt.scatter(training_set['date'], lr.predict(training_inputs))
plt.show()

plt.scatter(validation_set['date'], validation_set['cnt'])
plt.scatter(validation_set['date'], lr.predict(validation_inputs))
plt.show()

rmse=np.sqrt(((lr.predict(validation_inputs)-validation_outputs)**2).mean())
print('Root mean square error for this model:',rmse)
# Out:
# Root mean square error for this model: 925.663562982244
